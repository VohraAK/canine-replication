# %%
# !pip install transformers
# !pip install accelerate
# !pip install datasets
# !pip install evaluate
# Out:
# Requirement already satisfied: transformers in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (4.57.1)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from transformers) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from transformers) (2025.9.18)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from requests->transformers) (2025.10.5)
# Requirement already satisfied: accelerate in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (1.11.0)
# Requirement already satisfied: numpy>=1.17 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from accelerate) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from accelerate) (7.1.0)
# Requirement already satisfied: pyyaml in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from accelerate) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from accelerate) (2.8.0)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from accelerate) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from accelerate) (0.6.2)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from huggingface_hub>=0.21.0->accelerate) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from huggingface_hub>=0.21.0->accelerate) (2025.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from huggingface_hub>=0.21.0->accelerate) (1.2.0)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from huggingface_hub>=0.21.0->accelerate) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: setuptools in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2025.10.5)
# Requirement already satisfied: datasets in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (4.3.0)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from datasets) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: pyarrow>=21.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from datasets) (2.3.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2025.9.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.13.1)
# Requirement already satisfied: anyio in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from httpx<1.0.0->datasets) (4.11.0)
# Requirement already satisfied: certifi in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from httpx<1.0.0->datasets) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from httpx<1.0.0->datasets) (3.10)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: evaluate in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (0.4.6)
# Requirement already satisfied: datasets>=2.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from evaluate) (4.3.0)
# Requirement already satisfied: numpy>=1.17 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from evaluate) (2.3.3)
# Requirement already satisfied: dill in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from evaluate) (0.4.0)
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from evaluate) (2.3.2)
# Requirement already satisfied: requests>=2.19.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from evaluate) (2.32.5)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.9.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from evaluate) (0.36.0)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from datasets>=2.0.0->evaluate) (3.19.1)
# Requirement already satisfied: pyarrow>=21.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from datasets>=2.0.0->evaluate) (21.0.0)
# Requirement already satisfied: httpx<1.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from datasets>=2.0.0->evaluate) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.1)
# Requirement already satisfied: anyio in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (4.11.0)
# Requirement already satisfied: certifi in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (1.0.9)
# Requirement already satisfied: idna in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (3.10)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.0.0->evaluate) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from huggingface-hub>=0.7.0->evaluate) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from requests>=2.19.0->evaluate) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from anyio->httpx<1.0.0->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/envs/cs5316/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)

# %% [markdown]
# # 1. Training

# %%
MODEL = "xlm-roberta-base"
REPO = "xlm-roberta-base-uqa"
LEARNING_RATE = 2e-5
EPOCHS = 6

# %% [markdown]
# ### 1.1. Load Dataset

# %%
def filter_function(example):
    return not example['is_impossible']

# %%
from datasets import load_dataset

raw_datasets = load_dataset("uqa/UQA")
raw_datasets["train"] = raw_datasets["train"].filter(filter_function)
raw_datasets["validation"] = raw_datasets["validation"].filter(filter_function)
# Out:
# Filter: 100%|██████████| 124745/124745 [00:00<00:00, 149449.99 examples/s]
# Filter: 100%|██████████| 16824/16824 [00:00<00:00, 159822.46 examples/s]

# %% [markdown]
# ### 1.2. Load Model

# %%
from transformers import AutoTokenizer, AutoModelForQuestionAnswering

tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForQuestionAnswering.from_pretrained(MODEL)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### 1.3. Process Dataset

# %%
max_length = 384
stride = 128

def preprocess_training_examples(examples):
    questions = [q.strip() for q in examples["question"]]
    inputs = tokenizer(
        questions,
        examples["context"],
        max_length=max_length,
        truncation="only_second",
        stride=stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )

    offset_mapping = inputs.pop("offset_mapping")
    sample_map = inputs.pop("overflow_to_sample_mapping")
    answers = examples["answer"]
    answer_starts = examples["answer_start"]
    start_positions = []
    end_positions = []

    for i, offset in enumerate(offset_mapping):
        sample_idx = sample_map[i]
        answer = answers[sample_idx]
        start_char = answer_starts[sample_idx]
        end_char = answer_starts[sample_idx] + len(answer)
        sequence_ids = inputs.sequence_ids(i)

        idx = 0
        while sequence_ids[idx] != 1:
            idx += 1
        context_start = idx
        while sequence_ids[idx] == 1:
            idx += 1
        context_end = idx - 1

        if offset[context_start][0] > start_char or offset[context_end][1] < end_char:
            start_positions.append(0)
            end_positions.append(0)
        else:
            idx = context_start
            while idx <= context_end and offset[idx][0] <= start_char:
                idx += 1
            start_positions.append(idx - 1)

            idx = context_end
            while idx >= context_start and offset[idx][1] >= end_char:
                idx -= 1
            end_positions.append(idx + 1)

    inputs["start_positions"] = start_positions
    inputs["end_positions"] = end_positions
    return inputs

# %%
train_dataset = raw_datasets["train"].map(
    preprocess_training_examples,
    batched=True,
    remove_columns=raw_datasets["train"].column_names,
)
len(raw_datasets["train"]), len(train_dataset)

# %%
validation_dataset = raw_datasets["validation"].map(
    preprocess_training_examples,
    batched=True,
    remove_columns=raw_datasets["validation"].column_names,
)
len(raw_datasets["validation"]), len(validation_dataset)

# %% [markdown]
# ### 1.4. Start Training

# %%
from transformers import default_data_collator, TrainingArguments, Trainer

args = TrainingArguments(
    output_dir=REPO,
    num_train_epochs=EPOCHS,
    learning_rate=LEARNING_RATE,
    evaluation_strategy = "epoch",
    save_strategy = "epoch",
    gradient_accumulation_steps=8,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    weight_decay=0.01,
    fp16=True,
    push_to_hub=True
)

data_collator = default_data_collator

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=train_dataset,
    eval_dataset=validation_dataset,
    data_collator=data_collator,
    tokenizer=tokenizer
)

# %%
trainer.train()

# %% [markdown]
# # 2. Evaluation

# %% [markdown]
# ### 2.1. Prepare Dataset

# %%
from datasets import Dataset, DatasetDict

def merge_duplicate_ids(dataset):
    data_list = dataset.to_dict()
    grouped_data = {}

    for i in range(len(data_list['id'])):
        idx = data_list['id'][i]
        if idx not in grouped_data:
            grouped_data[idx] = {
                'id': idx,
                'title': data_list['title'][i],
                'context': data_list['context'][i],
                'question': data_list['question'][i],
                'is_impossible': data_list['is_impossible'][i],
                'answer': [data_list['answer'][i]],
                'answer_start': [data_list['answer_start'][i]]
            }
        else:
            grouped_data[idx]['answer'].append(data_list['answer'][i])
            grouped_data[idx]['answer_start'].append(data_list['answer_start'][i])

    merged_data = list(grouped_data.values())
    return merged_data

merged_train_data = merge_duplicate_ids(raw_datasets['train'])
merged_validation_data = merge_duplicate_ids(raw_datasets['validation'])

merged_train_dataset = Dataset.from_dict({k: [dic[k] for dic in merged_train_data] for k in merged_train_data[0]})
merged_validation_dataset = Dataset.from_dict({k: [dic[k] for dic in merged_validation_data] for k in merged_validation_data[0]})

dataset = DatasetDict({
    'train': merged_train_dataset,
    'validation': merged_validation_dataset
})

dataset

# %% [markdown]
# ### 2.2. Load Evaluation Functions

# %%
import evaluate

metric = evaluate.load("squad")

# %% [markdown]
# ### 2.3. Evaluate

# %%
import os
from tqdm import tqdm
from glob import glob
import torch
from transformers import AutoTokenizer, AutoModelForQuestionAnswering

# %%
def evaluate_batch(model, tokenizer, batch):
    inputs = tokenizer(batch["question"], batch["context"], padding="max_length", truncation=True, max_length=512, return_tensors="pt").to("cuda")
    with torch.no_grad():
        output = model(**inputs)
        start_logits, end_logits = output.start_logits, output.end_logits

    answers = []
    for i in range(len(start_logits)):
        start_idx = torch.argmax(start_logits[i])
        end_idx = torch.argmax(end_logits[i])
        answer = tokenizer.decode(inputs["input_ids"][i][start_idx:end_idx+1])
        answers.append(answer)

    return answers

# %%
def evaluate(model_dir, dataset):
    checkpoints = glob(f"{model_dir}/checkpoint-*")
    for checkpoint in checkpoints:
        tokenizer = AutoTokenizer.from_pretrained(checkpoint)
        model = AutoModelForQuestionAnswering.from_pretrained(checkpoint).to("cuda")

        predictions = []
        references = []

        batch_size = 16
        for i in tqdm(range(0, len(dataset["validation"]), batch_size)):
            batch = dataset["validation"][i: i + batch_size]
            preds = evaluate_batch_filtered(model, tokenizer, batch)
            for j in range(len(preds)):
                references.append({"id": batch["id"][j], "answers": [{"text": text, "answer_start": start} for text,
                                                                  start in zip(batch["answer"][j],
                                                                              batch["answer_start"][j])]})
                predictions.append({"id": batch["id"][j], "prediction_text": preds[j]})
        print(checkpoint)
        print(metric.compute(predictions=predictions, references=references))

# %%
evaluate(REPO, dataset)
